# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./cleaned_data.csv')

# %%
df.head()
# Out:
#        date    price                                address  bedrooms  \
# 0  29-04-24   480000   1307/60 A'beckett Street, Melbourne          2
# 1  27-03-24   815000   1103/108 Flinders Street, Melbourne          2
# 2  29-02-24  3350000      3801/35 Spring Street, Melbourne          3
# 3  29-02-24  3350000      3801/35 Spring Street, Melbourne          3
# 4   8 12 23   590000  508/181 Exhibition Street, Melbourne          2
#
#    bathrooms  parking   area  median_price  population average_age  zipcode  \
# 0          1        0   53.0        550000       47279    20 to 39     3000
# 1          2        1   93.0        550000       47279    20 to 39     3000
# 2          2        2  175.0    1072000000       47279    20 to 39     3000
# 3          2        2  175.0    1072000000       47279    20 to 39     3000
# 4          1        1   80.0        550000       47279    20 to 39     3000
#
#       state
# 0  Victoria
# 1  Victoria
# 2  Victoria
# 3  Victoria
# 4  Victoria

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55006 entries, 0 to 55005
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          55006 non-null  object
#  1   price         55006 non-null  int64
#  2   address       55006 non-null  object
#  3   bedrooms      55006 non-null  int64
#  4   bathrooms     55006 non-null  int64
#  5   parking       55006 non-null  int64
#  6   area          55006 non-null  float64
#  7   median_price  55006 non-null  int64
#  8   population    55006 non-null  int64
#  9   average_age   55006 non-null  object
#  10  zipcode       55006 non-null  int64
#  11  state         55006 non-null  object
# dtypes: float64(1), int64(7), object(4)
# memory usage: 5.0+ MB

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

x = df[['bedrooms', 'bathrooms', 'parking', 'area']]
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=1)
principle_components = pca.fit_transform(x_scaled)

# %%
pca_df = pd.DataFrame(principle_components, columns=["pca1"])

# %%
pca_df
# Out:
#            pca1
# 0     -1.621046
# 1     -0.533941
# 2      0.314764
# 3      0.314764
# 4     -1.614501
# ...         ...
# 55001 -0.743632
# 55002 -0.762911
# 55003  0.317591
# 55004 -0.768839
# 55005  0.317745
#
# [55006 rows x 1 columns]

# %%
final_df = pd.concat([df, pca_df], axis=1)
final_df
# Out:
#            date    price                                address  bedrooms  \
# 0      29-04-24   480000   1307/60 A'beckett Street, Melbourne          2
# 1      27-03-24   815000   1103/108 Flinders Street, Melbourne          2
# 2      29-02-24  3350000      3801/35 Spring Street, Melbourne          3
# 3      29-02-24  3350000      3801/35 Spring Street, Melbourne          3
# 4       8 12 23   590000  508/181 Exhibition Street, Melbourne          2
# ...         ...      ...                                    ...       ...
# 55001   1 10 20   298000              22 Clarke Cres, Katherine         3
# 55002  29-09-20   300000          12 McDonald Street, Katherine         3
# 55003   7 09 20   385000          20 Clarke Crescent, Katherine         3
# 55004  31-08-20   360000              10 Ixora Court, Katherine         3
# 55005  25-08-20   340000              6 Clough Court, Katherine         3
#
#        bathrooms  parking   area  median_price  population average_age  \
# 0              1        0   53.0        550000       47279    20 to 39
# 1              2        1   93.0        550000       47279    20 to 39
# 2              2        2  175.0    1072000000       47279    20 to 39
# 3              2        2  175.0    1072000000       47279    20 to 39
# 4              1        1   80.0        550000       47279    20 to 39
# ...          ...      ...    ...           ...         ...         ...
# 55001          1        5  817.0        375000        1484    20 to 39
# 55002          1        2  817.0        375000        1484    20 to 39
# 55003          2        2  817.0        375000        1484    20 to 39
# 55004          1        1  930.0        375000        1484    20 to 39
# 55005          2        2  852.0        375000        1484    20 to 39
#
#        zipcode                state      pca1
# 0         3000             Victoria -1.621046
# 1         3000             Victoria -0.533941
# 2         3000             Victoria  0.314764
# 3         3000             Victoria  0.314764
# 4         3000             Victoria -1.614501
# ...        ...                  ...       ...
# 55001      850   Northern Territory -0.743632
# 55002      850   Northern Territory -0.762911
# 55003      850   Northern Territory  0.317591
# 55004      850   Northern Territory -0.768839
# 55005      850   Northern Territory  0.317745
#
# [55006 rows x 13 columns]

# %%
plt.scatter(final_df['pca1'], final_df['price'])

# %%
from sklearn.linear_model import LinearRegression

x = final_df[['pca1']]
y = final_df['price']
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x), color='red')
